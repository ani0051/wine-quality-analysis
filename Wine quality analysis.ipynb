# %% [markdown]
# # Wine Quality Analysis (corizo project)

# %% [markdown]
# # All the work here is done by PRIYANSH CHHABRA AND ANANYA BISHT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("/Users/priyansh/Downloads/1613779-Red_wine_.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# 3      9.8      6.0
# 4      9.4      5.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1598 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1598 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
data = data.iloc[:,1:]
print(data.head())
# Out:
#    volatile acidity  citric acid  residual sugar  chlorides  \
# 0              0.70         0.00             1.9      0.076
# 1              0.88         0.00             2.6      0.098
# 2              0.76         0.04             2.3      0.092
# 3              0.28         0.56             1.9      0.075
# 4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# 3      9.8      6.0
# 4      9.4      5.0

# %%
data.describe()
# Out:
#        volatile acidity  citric acid  residual sugar    chlorides  \
# count       1599.000000  1599.000000     1599.000000  1599.000000
# mean           0.527821     0.270976        2.538806     0.087467
# std            0.179060     0.194801        1.409928     0.047065
# min            0.120000     0.000000        0.900000     0.012000
# 25%            0.390000     0.090000        1.900000     0.070000
# 50%            0.520000     0.260000        2.200000     0.079000
# 75%            0.640000     0.420000        2.600000     0.090000
# max            1.580000     1.000000       15.500000     0.611000
#
#        free sulfur dioxide  total sulfur dioxide      density           pH  \
# count          1599.000000           1598.000000  1599.000000  1598.000000
# mean             15.874922             46.433041     0.996747     3.498586
# std              10.460157             32.876249     0.001887     0.080346
# min               1.000000              6.000000     0.990070     2.740000
# 25%               7.000000             22.000000     0.995600     3.520000
# 50%              14.000000             38.000000     0.996750     3.520000
# 75%              21.000000             62.000000     0.997835     3.520000
# max              72.000000            289.000000     1.003690     3.900000
#
#          sulphates      alcohol      quality
# count  1599.000000  1599.000000  1598.000000
# mean      0.658149    10.422983     5.636421
# std       0.169507     1.065668     0.807665
# min       0.330000     8.400000     3.000000
# 25%       0.550000     9.500000     5.000000
# 50%       0.620000    10.200000     6.000000
# 75%       0.730000    11.100000     6.000000
# max       2.000000    14.900000     8.000000

# %%
data.corr()['quality']
# Out:
# volatile acidity       -0.390258
# citric acid             0.225867
# residual sugar          0.013756
# chlorides              -0.129011
# free sulfur dioxide    -0.050899
# total sulfur dioxide   -0.184699
# density                -0.174741
# pH                      0.133961
# sulphates               0.251118
# alcohol                 0.475943
# quality                 1.000000
# Name: quality, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,linewidth=0.5,center=0,cmap='coolwarm')
plt.show()

# %%
plt.hist(data.quality,bins=6,alpha=0.5,histtype='bar',ec='black')
plt.title('Distribution of the Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(data['quality'],data['pH'],palette="GnBu_d")
plt.show()
# Out:
# /Users/priyansh/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(x='quality',y='pH',data=data,palette='GnBu_d')
plt.title("Boxplot of Quality and pH")
plt.show()

# %%
ax = sns.boxplot(x='quality',y='alcohol',data=data,palette='GnBu_d')
plt.title("Boxplot of Quality and Alcohol")
plt.show()

# %%
py=sns.boxplot(x="quality",y="alcohol",data=data,palette="GnBu_d")
plt.title("Boxplot of Quality and residual sugar")
plt.show()

# %%
sns.boxplot(x="quality",y="density",data=data,palette="GnBu_d")
plt.title("Boxplot of Quality and Density")
plt.show()

# %%
sns.boxplot(x="quality",y="sulphates",data=data,palette="GnBu_d")
plt.title("Boxplot of Quality and Sulphates")
plt.show()

# %%
sns.boxplot(x="quality",y="chlorides",data=data,palette="GnBu_d")
plt.title("Boxplot of Quality and Chlorides")
plt.show()

# %%
sns.boxplot(x="quality",y="citric acid",data=data,palette="coolwarm")
plt.title("Boxplot of Quality and Citric Acid")
plt.show()

# %%
sns.boxplot(x="quality",y="alcohol",data=data,palette="coolwarm")
plt.title("Boxplot of Quality and Volatile Acidity")
plt.show()

# %%
sns.boxplot(x="quality",y="alcohol",data=data,palette="coolwarm")
plt.title("Boxplot of Quality and Fixed Acidity")
plt.show()
